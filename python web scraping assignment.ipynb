# %%
import pandas as _hex_pandas
import datetime as _hex_datetime
import json as _hex_json

# %%
hex_scheduled = _hex_json.loads("false")

# %%
hex_user_email = _hex_json.loads("\"example-user@example.com\"")

# %%
hex_run_context = _hex_json.loads("\"logic\"")

# %%
hex_timezone = _hex_json.loads("\"US/Eastern\"")

# %%
hex_project_id = _hex_json.loads("\"5ffaa5cd-d050-4591-ab86-ea2d990dd028\"")

# %%
hex_project_name = _hex_json.loads("\"python web scraping assignment\"")

# %%
hex_status = _hex_json.loads("\"\"")

# %%
hex_categories = _hex_json.loads("[]")

# %%
hex_color_palette = _hex_json.loads("[\"#4C78A8\",\"#F58518\",\"#E45756\",\"#72B7B2\",\"#54A24B\",\"#EECA3B\",\"#B279A2\",\"#FF9DA6\",\"#9D755D\",\"#BAB0AC\"]")

# %%
import requests 
import pandas as pd
from bs4 import BeautifulSoup
url = "https://webpages.charlotte.edu/mscipion/"
r = requests.get(url)
print(r)
soup = BeautifulSoup(r.text, "lxml")
table = soup.find("table")
headers = table.find_all("th")
print(headers)

titles = []
for i in headers:
    title = i.text 
    titles.append(title)
print(titles)
df = pd.DataFrame(columns=titles)
print(df)
rows = table.find_all("tr")
rows[1:2]
# Out:
# <Response [200]>
# [<th>Student</th>, <th>Favourite Computer Language</th>, <th>Years of Experience</th>]
# ['Student', 'Favourite Computer Language', 'Years of Experience']
# Empty DataFrame
# Columns: [Student, Favourite Computer Language, Years of Experience]
# Index: []
# [<tr>
#  <td>Fred</td>
#  <td>Kotlin</td>
#  <td>4</td>
#  </tr>]

# %%
for i in rows[1:]:
    data = i.find_all("td")
    row = [tr.text for tr in data]
    l = len(df)
    df.loc[l]=row

df.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Student</th>
#       <th>Favourite Computer Language</th>
#       <th>Years of Experience</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Fred</td>
#       <td>Kotlin</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Paula</td>
#       <td>Python</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Ernst</td>
#       <td>Java</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Isabel</td>
#       <td>C++</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Tony</td>
# ...
